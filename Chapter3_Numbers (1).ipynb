# %%
60 * 60

# %%
seconds_per_hour = 60 * 60
seconds_per_hour

# %%
seconds_per_hour * 24

# %%
seconds_per_day = seconds_per_hour * 24
seconds_per_day

# %%
seconds_per_day / seconds_per_hour

# %%
seconds_per_day // seconds_per_hour

# %%
Yes, the number is the same. The floating division shows 
24.0 and the integer divis
